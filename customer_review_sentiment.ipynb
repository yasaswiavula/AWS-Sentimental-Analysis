# %% [markdown]
# # Amazon Comprehend - Sentiment Analysis
# ###  Assess sentiment of customer reviews on Amazon Products
#
# Objective: Use Comprehend Service to detect sentiment
#
# Input: Customer Review title and text
# Output: Overall sentiment and scores for Positive, Negative, Neutral, Mixed
#
# https://docs.aws.amazon.com/comprehend/latest/dg/how-sentiment.html
#
# Dataset and Problem Description:
# https://www.kaggle.com/datasets/datafiniti/consumer-reviews-of-amazon-products/

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import re

# Connect to Comprehend to get Sentiment
import boto3

# %% [markdown]
# ### Prepare Training and Test data

# %%
bucket='amazon-reviews-multilingual' # Or whatever you called your bucket
data_key = 'Datafiniti_Amazon_Consumer_Reviews_of_Amazon_Products.csv' # Where the file is within your bucket
data_location = 's3://{}/{}'.format(bucket, data_key)
df = pd.read_csv(data_location)

# %%
print('Rows: {0}, Columns: {1}'.format(df.shape[0],df.shape[1]))
# Out:
# Rows: 5000, Columns: 24

# %%
df.index.max()
# Out:
# 4999

# %%
df.columns
# Out:
# Index(['id', 'dateAdded', 'dateUpdated', 'name', 'asins', 'brand',
#        'categories', 'primaryCategories', 'imageURLs', 'keys', 'manufacturer',
#        'manufacturerNumber', 'reviews.date', 'reviews.dateAdded',
#        'reviews.dateSeen', 'reviews.doRecommend', 'reviews.id',
#        'reviews.numHelpful', 'reviews.rating', 'reviews.sourceURLs',
#        'reviews.text', 'reviews.title', 'reviews.username', 'sourceURLs'],
#       dtype='object')

# %%
df.isna().any(axis=0)
# Out:
# id                     False
# dateAdded              False
# dateUpdated            False
# name                   False
# asins                  False
# brand                  False
# categories             False
# primaryCategories      False
# imageURLs              False
# keys                   False
# manufacturer           False
# manufacturerNumber     False
# reviews.date           False
# reviews.dateAdded       True
# reviews.dateSeen       False
# reviews.doRecommend    False
# reviews.id              True
# reviews.numHelpful     False
# reviews.rating         False
# reviews.sourceURLs     False
# reviews.text           False
# reviews.title           True
# reviews.username        True
# sourceURLs             False
# dtype: bool

# %%
# Look for any rows that have NA
rows_missing_values = df.isna().any(axis=1)

# %%
df[rows_missing_values]
# Out:
#                         id             dateAdded           dateUpdated  \
# 0     AVqVGZNvQMlgsOJE6eUY  2017-03-03T16:56:05Z  2018-10-25T16:36:31Z
# 1     AVqVGZNvQMlgsOJE6eUY  2017-03-03T16:56:05Z  2018-10-25T16:36:31Z
# 2     AVqVGZNvQMlgsOJE6eUY  2017-03-03T16:56:05Z  2018-10-25T16:36:31Z
# 3     AVqVGZNvQMlgsOJE6eUY  2017-03-03T16:56:05Z  2018-10-25T16:36:31Z
# 4     AVqVGZNvQMlgsOJE6eUY  2017-03-03T16:56:05Z  2018-10-25T16:36:31Z
# ...                    ...                   ...                   ...
# 4995  AVqkIdZiv8e3D1O-leaJ  2017-03-06T14:59:25Z  2017-09-04T11:19:31Z
# 4996  AVqkIdZiv8e3D1O-leaJ  2017-03-06T14:59:25Z  2017-09-04T11:19:31Z
# 4997  AVqkIdZiv8e3D1O-leaJ  2017-03-06T14:59:25Z  2017-09-04T11:19:31Z
# 4998  AVqkIdZiv8e3D1O-leaJ  2017-03-06T14:59:25Z  2017-09-04T11:19:31Z
# 4999  AVqkIdZiv8e3D1O-leaJ  2017-03-06T14:59:25Z  2017-09-04T11:19:31Z
#
#                                                    name       asins   brand  \
# 0     Amazon Kindle E-Reader 6" Wifi (8th Generation...  B00ZV9PXP2  Amazon
# 1     Amazon Kindle E-Reader 6" Wifi (8th Generation...  B00ZV9PXP2  Amazon
# 2     Amazon Kindle E-Reader 6" Wifi (8th Generation...  B00ZV9PXP2  Amazon
# 3     Amazon Kindle E-Reader 6" Wifi (8th Generation...  B00ZV9PXP2  Amazon
# 4     Amazon Kindle E-Reader 6" Wifi (8th Generation...  B00ZV9PXP2  Amazon
# ...                                                 ...         ...     ...
# 4995  Fire Tablet with Alexa, 7" Display, 16 GB, Mag...  B018Y224PY  Amazon
# 4996  Fire Tablet with Alexa, 7" Display, 16 GB, Mag...  B018Y224PY  Amazon
# 4997  Fire Tablet with Alexa, 7" Display, 16 GB, Mag...  B018Y224PY  Amazon
# 4998  Fire Tablet with Alexa, 7" Display, 16 GB, Mag...  B018Y224PY  Amazon
# 4999  Fire Tablet with Alexa, 7" Display, 16 GB, Mag...  B018Y224PY  Amazon
#
#                                              categories primaryCategories  \
# 0     Computers,Electronics Features,Tablets,Electro...       Electronics
# 1     Computers,Electronics Features,Tablets,Electro...       Electronics
# 2     Computers,Electronics Features,Tablets,Electro...       Electronics
# 3     Computers,Electronics Features,Tablets,Electro...       Electronics
# 4     Computers,Electronics Features,Tablets,Electro...       Electronics
# ...                                                 ...               ...
# 4995  Tablets,Fire Tablets,Electronics,iPad & Tablet...       Electronics
# 4996  Tablets,Fire Tablets,Electronics,iPad & Tablet...       Electronics
# 4997  Tablets,Fire Tablets,Electronics,iPad & Tablet...       Electronics
# 4998  Tablets,Fire Tablets,Electronics,iPad & Tablet...       Electronics
# 4999  Tablets,Fire Tablets,Electronics,iPad & Tablet...       Electronics
#
#                                               imageURLs  \
# 0     https://pisces.bbystatic.com/image2/BestBuy_US...
# 1     https://pisces.bbystatic.com/image2/BestBuy_US...
# 2     https://pisces.bbystatic.com/image2/BestBuy_US...
# 3     https://pisces.bbystatic.com/image2/BestBuy_US...
# 4     https://pisces.bbystatic.com/image2/BestBuy_US...
# ...                                                 ...
# 4995  https://images-na.ssl-images-amazon.com/images...
# 4996  https://images-na.ssl-images-amazon.com/images...
# 4997  https://images-na.ssl-images-amazon.com/images...
# 4998  https://images-na.ssl-images-amazon.com/images...
# 4999  https://images-na.ssl-images-amazon.com/images...
#
#                                                    keys  ...  \
# 0     allnewkindleereaderblack6glarefreetouchscreend...  ...
# 1     allnewkindleereaderblack6glarefreetouchscreend...  ...
# 2     allnewkindleereaderblack6glarefreetouchscreend...  ...
# 3     allnewkindleereaderblack6glarefreetouchscreend...  ...
# 4     allnewkindleereaderblack6glarefreetouchscreend...  ...
# ...                                                 ...  ...
# 4995  841667103150,0841667103150,firetabletwithalexa...  ...
# 4996  841667103150,0841667103150,firetabletwithalexa...  ...
# 4997  841667103150,0841667103150,firetabletwithalexa...  ...
# 4998  841667103150,0841667103150,firetabletwithalexa...  ...
# 4999  841667103150,0841667103150,firetabletwithalexa...  ...
#
#                                        reviews.dateSeen reviews.doRecommend  \
# 0     2018-05-27T00:00:00Z,2017-09-18T00:00:00Z,2017...               False
# 1     2018-05-27T00:00:00Z,2017-07-07T00:00:00Z,2017...                True
# 2                                  2018-05-27T00:00:00Z                True
# 3                                  2018-10-09T00:00:00Z                True
# 4                                  2018-05-27T00:00:00Z                True
# ...                                                 ...                 ...
# 4995  2017-04-30T02:06:48.451Z,2017-06-07T08:20:48.408Z                True
# 4996  2017-04-30T02:07:00.236Z,2017-06-07T08:20:55.199Z                True
# 4997  2017-04-30T02:03:13.567Z,2017-06-07T08:10:47.953Z                True
# 4998  2017-04-30T02:06:56.574Z,2017-06-07T08:20:53.942Z                True
# 4999  2017-04-03T03:55:09.054Z,2017-04-30T02:03:18.1...                True
#
#        reviews.id reviews.numHelpful reviews.rating  \
# 0             NaN                  0              3
# 1             NaN                  0              5
# 2             NaN                  0              4
# 3     177283626.0                  3              5
# 4             NaN                  0              5
# ...           ...                ...            ...
# 4995          NaN                  0              5
# 4996          NaN                  1              5
# 4997          NaN                  8              4
# 4998          NaN                  0              5
# 4999          NaN                  0              5
#
#                                      reviews.sourceURLs  \
# 0     http://reviews.bestbuy.com/3545/5442403/review...
# 1     http://reviews.bestbuy.com/3545/5442403/review...
# 2     https://reviews.bestbuy.com/3545/5442403/revie...
# 3     https://redsky.target.com/groot-domain-api/v1/...
# 4     https://reviews.bestbuy.com/3545/5442403/revie...
# ...                                                 ...
# 4995  http://reviews.bestbuy.com/3545/5025900/review...
# 4996  http://reviews.bestbuy.com/3545/5025900/review...
# 4997  http://reviews.bestbuy.com/3545/5025900/review...
# 4998  http://reviews.bestbuy.com/3545/5025900/review...
# 4999  http://reviews.bestbuy.com/3545/5025900/review...
#
#                                            reviews.text  \
# 0     I thought it would be as big as small paper bu...
# 1     This kindle is light and easy to use especiall...
# 2     Didnt know how much i'd use a kindle so went f...
# 3     I am 100 happy with my purchase. I caught it o...
# 4     Solid entry level Kindle. Great for kids. Gift...
# ...                                                 ...
# 4995  This is a great tablet for the price. Amazon i...
# 4996  This tablet is the perfect size and so easy to...
# 4997  Purchased this for my son. Has room to upgrade...
# 4998  I had some thoughts about getting this for a 5...
# 4999  this is a steal, have 8 gb model as well.This ...
#
#                                      reviews.title  reviews.username  \
# 0                                        Too small            llyyue
# 1     Great light reader. Easy to use at the beach            Charmi
# 2                              Great for the price      johnnyjojojo
# 3                                      A Great Buy           Kdperry
# 4         Solid entry-level Kindle. Great for kids       Johnnyblack
# ...                                            ...               ...
# 4995                                  Good product             litle
# 4996                                  Great Tablet            gracie
# 4997               Great for kids or smaller needs              Hawk
# 4998                  Very sturdy for a 5 year old           Mrbilly
# 4999                           great little tablet            tabman
#
#                                              sourceURLs
# 0     https://www.newegg.com/Product/Product.aspx%25...
# 1     https://www.newegg.com/Product/Product.aspx%25...
# 2     https://www.newegg.com/Product/Product.aspx%25...
# 3     https://www.newegg.com/Product/Product.aspx%25...
# 4     https://www.newegg.com/Product/Product.aspx%25...
# ...                                                 ...
# 4995  https://www.barcodable.com/upc/841667103150,ht...
# 4996  https://www.barcodable.com/upc/841667103150,ht...
# 4997  https://www.barcodable.com/upc/841667103150,ht...
# 4998  https://www.barcodable.com/upc/841667103150,ht...
# 4999  https://www.barcodable.com/upc/841667103150,ht...
#
# [5000 rows x 24 columns]

# %%
df['reviews.title'] = df['reviews.title'].fillna(' ')
df['reviews.text'] = df['reviews.text'].fillna(' ')

# %%
# Replace embedded new lines, tabs and carriage return
pattern = r'[\n\t\r]+'

# %%
# Use Regex module sub method to identify patterns of interest and replace the matching text.
text = 'ab,cd\n\tef'

print('original text:', text)

print('after substituition:', re.sub(pattern,' ', text))
# Out:
# original text: ab,cd
# 	ef
# after substituition: ab,cd ef

# %%
df['name'] = df['name'].map(lambda x: re.sub(pattern,' ',x))
df['reviews.title'] = df['reviews.title'].map(lambda x: re.sub(pattern,' ',x))
df['reviews.text'] = df['reviews.text'].map(lambda x: re.sub(pattern,' ',x))

# %%
df.head()
# Out:
#                      id             dateAdded           dateUpdated  \
# 0  AVqVGZNvQMlgsOJE6eUY  2017-03-03T16:56:05Z  2018-10-25T16:36:31Z
# 1  AVqVGZNvQMlgsOJE6eUY  2017-03-03T16:56:05Z  2018-10-25T16:36:31Z
# 2  AVqVGZNvQMlgsOJE6eUY  2017-03-03T16:56:05Z  2018-10-25T16:36:31Z
# 3  AVqVGZNvQMlgsOJE6eUY  2017-03-03T16:56:05Z  2018-10-25T16:36:31Z
# 4  AVqVGZNvQMlgsOJE6eUY  2017-03-03T16:56:05Z  2018-10-25T16:36:31Z
#
#                                                 name       asins   brand  \
# 0  Amazon Kindle E-Reader 6" Wifi (8th Generation...  B00ZV9PXP2  Amazon
# 1  Amazon Kindle E-Reader 6" Wifi (8th Generation...  B00ZV9PXP2  Amazon
# 2  Amazon Kindle E-Reader 6" Wifi (8th Generation...  B00ZV9PXP2  Amazon
# 3  Amazon Kindle E-Reader 6" Wifi (8th Generation...  B00ZV9PXP2  Amazon
# 4  Amazon Kindle E-Reader 6" Wifi (8th Generation...  B00ZV9PXP2  Amazon
#
#                                           categories primaryCategories  \
# 0  Computers,Electronics Features,Tablets,Electro...       Electronics
# 1  Computers,Electronics Features,Tablets,Electro...       Electronics
# 2  Computers,Electronics Features,Tablets,Electro...       Electronics
# 3  Computers,Electronics Features,Tablets,Electro...       Electronics
# 4  Computers,Electronics Features,Tablets,Electro...       Electronics
#
#                                            imageURLs  \
# 0  https://pisces.bbystatic.com/image2/BestBuy_US...
# 1  https://pisces.bbystatic.com/image2/BestBuy_US...
# 2  https://pisces.bbystatic.com/image2/BestBuy_US...
# 3  https://pisces.bbystatic.com/image2/BestBuy_US...
# 4  https://pisces.bbystatic.com/image2/BestBuy_US...
#
#                                                 keys  ...  \
# 0  allnewkindleereaderblack6glarefreetouchscreend...  ...
# 1  allnewkindleereaderblack6glarefreetouchscreend...  ...
# 2  allnewkindleereaderblack6glarefreetouchscreend...  ...
# 3  allnewkindleereaderblack6glarefreetouchscreend...  ...
# 4  allnewkindleereaderblack6glarefreetouchscreend...  ...
#
#                                     reviews.dateSeen reviews.doRecommend  \
# 0  2018-05-27T00:00:00Z,2017-09-18T00:00:00Z,2017...               False
# 1  2018-05-27T00:00:00Z,2017-07-07T00:00:00Z,2017...                True
# 2                               2018-05-27T00:00:00Z                True
# 3                               2018-10-09T00:00:00Z                True
# 4                               2018-05-27T00:00:00Z                True
#
#     reviews.id reviews.numHelpful reviews.rating  \
# 0          NaN                  0              3
# 1          NaN                  0              5
# 2          NaN                  0              4
# 3  177283626.0                  3              5
# 4          NaN                  0              5
#
#                                   reviews.sourceURLs  \
# 0  http://reviews.bestbuy.com/3545/5442403/review...
# 1  http://reviews.bestbuy.com/3545/5442403/review...
# 2  https://reviews.bestbuy.com/3545/5442403/revie...
# 3  https://redsky.target.com/groot-domain-api/v1/...
# 4  https://reviews.bestbuy.com/3545/5442403/revie...
#
#                                         reviews.text  \
# 0  I thought it would be as big as small paper bu...
# 1  This kindle is light and easy to use especiall...
# 2  Didnt know how much i'd use a kindle so went f...
# 3  I am 100 happy with my purchase. I caught it o...
# 4  Solid entry level Kindle. Great for kids. Gift...
#
#                                   reviews.title  reviews.username  \
# 0                                     Too small            llyyue
# 1  Great light reader. Easy to use at the beach            Charmi
# 2                           Great for the price      johnnyjojojo
# 3                                   A Great Buy           Kdperry
# 4      Solid entry-level Kindle. Great for kids       Johnnyblack
#
#                                           sourceURLs
# 0  https://www.newegg.com/Product/Product.aspx%25...
# 1  https://www.newegg.com/Product/Product.aspx%25...
# 2  https://www.newegg.com/Product/Product.aspx%25...
# 3  https://www.newegg.com/Product/Product.aspx%25...
# 4  https://www.newegg.com/Product/Product.aspx%25...
#
# [5 rows x 24 columns]

# %%
df['reviews.text'].head()
# Out:
# 0    I thought it would be as big as small paper bu...
# 1    This kindle is light and easy to use especiall...
# 2    Didnt know how much i'd use a kindle so went f...
# 3    I am 100 happy with my purchase. I caught it o...
# 4    Solid entry level Kindle. Great for kids. Gift...
# Name: reviews.text, dtype: object

# %%
# Some examples of review title and body
for i in range(10):
    print(df.iloc[i]['reviews.title'] + ' - ' + df.iloc[i]['reviews.text'])
    print()
# Out:
# Too small - I thought it would be as big as small paper but turn out to be just like my palm. I think it is too small to read on it... not very comfortable as regular Kindle. Would definitely recommend a paperwhite instead.
#
# Great light reader. Easy to use at the beach - This kindle is light and easy to use especially at the beach!!!
#
# Great for the price - Didnt know how much i'd use a kindle so went for the lower end. im happy with it, even if its a little dark
#
# A Great Buy - I am 100 happy with my purchase. I caught it on sale at a really good price. I am normally a real book person, but I have a 1 year old who loves ripping up pages. The Kindle prevents that, it's extremely portable (it fits better in my purse than a giant book), and I have it loaded with lots of books. I finish one and start another, without having to go store. It serves all my needs. I picked this one over the Paperwhite because the price was unbeatable and the only difference that I could see was this one wasn't backlit. A simple book light from the Dollar tree solves that issue. This is my second Kindle (the first being the old Keyboard model, which I put down because I fell out of love with the keyboard. Lol) and it most likely won't be my last.
#
# Solid entry-level Kindle. Great for kids - Solid entry level Kindle. Great for kids. Gifted for a kid of my friend and they love to use it to read more than their iPads. battery is good but higher model is a bit better.
#
# Good ebook - This make an excellent ebook reader. Don't expect much from this device except to read basic ebooks. The good thing is it's cheap and good to read in the sun.
#
# Light Weight - Makes a world of difference when taking books on the go! - I ordered this for my daughter, as I have the black paperwhite, and I love it. I read quite a bit and the larger books were driving me crazy having to hold them up while laying down, or wanting to take a book on vacation and lugging around a thick paperback, with this I can throw it in my bag and read anywhere. Its light weight, easy to use, the battery life lasts for weeks, which makes it an all around awesome device. My daughter is in public school and they offer an online library for E-Readers, so she can now download books for free from school! You can also download your own public library app (if your county offers that) and read free from there as well. You can shop for e-books straight from the device through Amazon.com.
#
# not good quality - I bought my Kindle about 2 months ago and the battery is already dead and will not charge
#
# best ebook - amazon kindle is always the best ebook, upgrade every new model
#
# Great Product - It's beyond my expectation, and it can even show music score. Not fast turning though.

# %% [markdown]
# ### Get Sentiment of Reviews using Comprehend AI Service

# %%
session = boto3.Session(region_name='us-east-2')

# %%
from botocore.config import Config
client = session.client('comprehend', config=Config(connect_timeout=5, read_timeout=60, retries={'max_attempts': 20}))
print(client.meta.config.retries)
# Out:
# {'total_max_attempts': 21, 'mode': 'legacy'}

# %%
# let's Try some examples
sentiment = client.detect_sentiment(
    Text="It's insulting that @awscloud marked an EBS volume limit increase support request as low severity but I can't do anything while I wait.",
    LanguageCode='en'
)

# %%
sentiment['Sentiment'],sentiment['SentimentScore']
# Out:
# ('NEGATIVE',
#  {'Positive': 0.0009363636490888894,
#   'Negative': 0.965487003326416,
#   'Neutral': 0.03050602786242962,
#   'Mixed': 0.0030704874079674482})

# %%
# %%time
# Sentiment of reviews -
# One roundtrip to comprehend service for each review
for i in range(15):
    review = df.iloc[i]['reviews.title'] + ' - ' + df.iloc[i]['reviews.text']
    print(review)
    sentiment = client.detect_sentiment(Text=review,LanguageCode='en')
    print(sentiment['Sentiment'])
    print()
# Out:
# Too small - I thought it would be as big as small paper but turn out to be just like my palm. I think it is too small to read on it... not very comfortable as regular Kindle. Would definitely recommend a paperwhite instead.
# NEGATIVE
#
# Great light reader. Easy to use at the beach - This kindle is light and easy to use especially at the beach!!!
# POSITIVE
#
# Great for the price - Didnt know how much i'd use a kindle so went for the lower end. im happy with it, even if its a little dark
# POSITIVE
#
# A Great Buy - I am 100 happy with my purchase. I caught it on sale at a really good price. I am normally a real book person, but I have a 1 year old who loves ripping up pages. The Kindle prevents that, it's extremely portable (it fits better in my purse than a giant book), and I have it loaded with lots of books. I finish one and start another, without having to go store. It serves all my needs. I picked this one over the Paperwhite because the price was unbeatable and the only difference that I could see was this one wasn't backlit. A simple book light from the Dollar tree solves that issue. This is my second Kindle (the first being the old Keyboard model, which I put down because I fell out of love with the keyboard. Lol) and it most likely won't be my last.
# POSITIVE
#
# Solid entry-level Kindle. Great for kids - Solid entry level Kindle. Great for kids. Gifted for a kid of my friend and they love to use it to read more than their iPads. battery is good but higher model is a bit better.
# POSITIVE
#
# Good ebook - This make an excellent ebook reader. Don't expect much from this device except to read basic ebooks. The good thing is it's cheap and good to read in the sun.
# POSITIVE
#
# Light Weight - Makes a world of difference when taking books on the go! - I ordered this for my daughter, as I have the black paperwhite, and I love it. I read quite a bit and the larger books were driving me crazy having to hold them up while laying down, or wanting to take a book on vacation and lugging around a thick paperback, with this I can throw it in my bag and read anywhere. Its light weight, easy to use, the battery life lasts for weeks, which makes it an all around awesome device. My daughter is in public school and they offer an online library for E-Readers, so she can now download books for free from school! You can also download your own public library app (if your county offers that) and read free from there as well. You can shop for e-books straight from the device through Amazon.com.
# POSITIVE
#
# not good quality - I bought my Kindle about 2 months ago and the battery is already dead and will not charge
# NEGATIVE
#
# best ebook - amazon kindle is always the best ebook, upgrade every new model
# POSITIVE
#
# Great Product - It's beyond my expectation, and it can even show music score. Not fast turning though.
# POSITIVE
#
# Good price excellent reader - If you really want to have a good read on something digital this is the item you're looking for. It really is lightweight and highly functional. The battery lasts a long time and the screen is easy on the eyes. The only difficulty sometimes is reading in extremely bright environments. Overall an excellent buy.
# POSITIVE
#
# feels like a real book - Love my kindle, makes reading at night so easy and it feels like you are reading a real book.
# POSITIVE
#
# Great readers - Good product for child. Who only need to read the books
# POSITIVE
#
# Just what my grandson wanted - This Kindle is a convenient size yet lettering is easy to read.
# POSITIVE
#
# Great for reading on the go - I use this every day on my commute. Great battery life, no backlight but very readable with normal lighting. I like the built in dictionary. Email yourself pdf or mobi files for easy transfers.
# POSITIVE
#
# CPU times: user 45 ms, sys: 211 µs, total: 45.2 ms
# Wall time: 876 ms

# %%
# %%time
# Batch Processing Upto 25 reviews in one round trip - 5,000 reviews in total
# Get sentiment for all reviews (25 reviews at a time)
step = 25
results = []

for i in range(0,df.shape[0],step):
    print('***',i,i+step)
    review = list((df.iloc[i:(i+step)]['reviews.title'] + ' - ' + df.iloc[i:(i+step)]['reviews.text'].str.slice(0,4000)).values)    
    #print(review)
    
    # initialize place holder for return values
    temp_results = ['']*len(review)

    sentiment = client.batch_detect_sentiment(TextList=review,LanguageCode='en')

    # Get the sentiment
    for s in sentiment['ResultList']:
        #print(s['Index']+i,s['Sentiment'])
        temp_results[s['Index']] = s['Sentiment']

    # Check for errors
    for s in sentiment['ErrorList']:
        #print(s['Index']+i,s['ErrorCode'])    
        temp_results[s['Index']] = s['ErrorCode']

    results.extend(temp_results)
# Out:
# *** 0 25
# *** 25 50
# *** 50 75
# *** 75 100
# *** 100 125
# *** 125 150
# *** 150 175
# *** 175 200
# *** 200 225
# *** 225 250
# *** 250 275
# *** 275 300
# *** 300 325
# *** 325 350
# *** 350 375
# *** 375 400
# *** 400 425
# *** 425 450
# *** 450 475
# *** 475 500
# *** 500 525
# *** 525 550
# *** 550 575
# *** 575 600
# *** 600 625
# *** 625 650
# *** 650 675
# *** 675 700
# *** 700 725
# *** 725 750
# *** 750 775
# *** 775 800
# *** 800 825
# *** 825 850
# *** 850 875
# *** 875 900
# *** 900 925
# *** 925 950
# *** 950 975
# *** 975 1000
# *** 1000 1025
# *** 1025 1050
# *** 1050 1075
# *** 1075 1100
# *** 1100 1125
# *** 1125 1150
# *** 1150 1175
# *** 1175 1200
# *** 1200 1225
# *** 1225 1250
# *** 1250 1275
# *** 1275 1300
# *** 1300 1325
# *** 1325 1350
# *** 1350 1375
# *** 1375 1400
# *** 1400 1425
# *** 1425 1450
# *** 1450 1475
# *** 1475 1500
# *** 1500 1525
# *** 1525 1550
# *** 1550 1575
# *** 1575 1600
# *** 1600 1625
# *** 1625 1650
# *** 1650 1675
# *** 1675 1700
# *** 1700 1725
# *** 1725 1750
# *** 1750 1775
# *** 1775 1800
# *** 1800 1825
# *** 1825 1850
# *** 1850 1875
# *** 1875 1900
# *** 1900 1925
# *** 1925 1950
# *** 1950 1975
# *** 1975 2000
# *** 2000 2025
# *** 2025 2050
# *** 2050 2075
# *** 2075 2100
# *** 2100 2125
# *** 2125 2150
# *** 2150 2175
# *** 2175 2200
# *** 2200 2225
# *** 2225 2250
# *** 2250 2275
# *** 2275 2300
# *** 2300 2325
# *** 2325 2350
# *** 2350 2375
# *** 2375 2400
# *** 2400 2425
# *** 2425 2450
# *** 2450 2475
# *** 2475 2500
# *** 2500 2525
# *** 2525 2550
# *** 2550 2575
# *** 2575 2600
# *** 2600 2625
# *** 2625 2650
# *** 2650 2675
# *** 2675 2700
# *** 2700 2725
# *** 2725 2750
# *** 2750 2775
# *** 2775 2800
# *** 2800 2825
# *** 2825 2850
# *** 2850 2875
# *** 2875 2900
# *** 2900 2925
# *** 2925 2950
# *** 2950 2975
# *** 2975 3000
# *** 3000 3025
# *** 3025 3050
# *** 3050 3075
# *** 3075 3100
# *** 3100 3125
# *** 3125 3150
# *** 3150 3175
# *** 3175 3200
# *** 3200 3225
# *** 3225 3250
# *** 3250 3275
# *** 3275 3300
# *** 3300 3325
# *** 3325 3350
# *** 3350 3375
# *** 3375 3400
# *** 3400 3425
# *** 3425 3450
# *** 3450 3475
# *** 3475 3500
# *** 3500 3525
# *** 3525 3550
# *** 3550 3575
# *** 3575 3600
# *** 3600 3625
# *** 3625 3650
# *** 3650 3675
# *** 3675 3700
# *** 3700 3725
# *** 3725 3750
# *** 3750 3775
# *** 3775 3800
# *** 3800 3825
# *** 3825 3850
# *** 3850 3875
# *** 3875 3900
# *** 3900 3925
# *** 3925 3950
# *** 3950 3975
# *** 3975 4000
# *** 4000 4025
# *** 4025 4050
# *** 4050 4075
# *** 4075 4100
# *** 4100 4125
# *** 4125 4150
# *** 4150 4175
# *** 4175 4200
# *** 4200 4225
# *** 4225 4250
# *** 4250 4275
# *** 4275 4300
# *** 4300 4325
# *** 4325 4350
# *** 4350 4375
# *** 4375 4400
# *** 4400 4425
# *** 4425 4450
# *** 4450 4475
# *** 4475 4500
# *** 4500 4525
# *** 4525 4550
# *** 4550 4575
# *** 4575 4600
# *** 4600 4625
# *** 4625 4650
# *** 4650 4675
# *** 4675 4700
# *** 4700 4725
# *** 4725 4750
# *** 4750 4775
# *** 4775 4800
# *** 4800 4825
# *** 4825 4850
# *** 4850 4875
# *** 4875 4900
# *** 4900 4925
# *** 4925 4950
# *** 4950 4975
# *** 4975 5000
# CPU times: user 1.05 s, sys: 63.2 ms, total: 1.11 s
# Wall time: 1min 27s

# %%
print(results)
# Out:
# ['NEGATIVE', 'POSITIVE', 'POSITIVE', 'POSITIVE', 'POSITIVE', 'POSITIVE', 'POSITIVE', 'NEGATIVE', 'POSITIVE', 'POSITIVE', 'POSITIVE', 'POSITIVE', 'POSITIVE', 'POSITIVE', 'POSITIVE', 'MIXED', 'POSITIVE', 'POSITIVE', 'POSITIVE', 'MIXED', 'NEGATIVE', 'MIXED', 'POSITIVE', 'POSITIVE', 'POSITIVE', 'POSITIVE', 'POSITIVE', 'POSITIVE', 'POSITIVE', 'MIXED', 'POSITIVE', 'POSITIVE', 'POSITIVE', 'POSITIVE', 'POSITIVE', 'POSITIVE', 'POSITIVE', 'POSITIVE', 'POSITIVE', 'POSITIVE', 'POSITIVE', 'POSITIVE', 'POSITIVE', 'POSITIVE', 'POSITIVE', 'POSITIVE', 'POSITIVE', 'POSITIVE', 'POSITIVE', 'MIXED', 'POSITIVE', 'POSITIVE', 'POSITIVE', 'POSITIVE', 'POSITIVE', 'POSITIVE', 'POSITIVE', 'POSITIVE', 'POSITIVE', 'POSITIVE', 'POSITIVE', 'POSITIVE', 'POSITIVE', 'POSITIVE', 'POSITIVE', 'MIXED', 'POSITIVE', 'POSITIVE', 'POSITIVE', 'POSITIVE', 'NEGATIVE', 'POSITIVE', 'NEGATIVE', 'POSITIVE', 'POSITIVE', 'NEGATIVE', 'POSITIVE', 'POSITIVE', 'MIXED', 'POSITIVE', 'NEGATIVE', 'POSITIVE', 'MIXED', 'POSITIVE', 'POSITIVE', 'POSITIVE', 'POSITIVE', 'POSITIVE', 'POSITIVE', 'POSITIVE', 'POSITIVE', 'MIXED', 'POSITIVE', 'NEGATIVE', 'POSITIVE', 'POSITIVE', 'POSITIVE', 'POSITIVE', 'NEUTRAL', 'POSITIVE', 'POSITIVE', 'POSITIVE', 'POSITIVE', 'POSITIVE', 'MIXED', 'POSITIVE', 'POSITIVE', 'MIXED', 'POSITIVE', 'POSITIVE', 'POSITIVE', 'POSITIVE', 'POSITIVE', 'POSITIVE', 'POSITIVE', 'POSITIVE', 'POSITIVE', 'POSITIVE', 'POSITIVE', 'POSITIVE', 'POSITIVE', 'POSITIVE', 'POSITIVE', 'MIXED', 'MIXED', 'POSITIVE', 'POSITIVE', 'POSITIVE', 'MIXED', 'POSITIVE', 'MIXED', 'POSITIVE', 'POSITIVE', 'POSITIVE', 'POSITIVE', 'POSITIVE', 'POSITIVE', 'POSITIVE', 'POSITIVE', 'POSITIVE', 'POSITIVE', 'POSITIVE', 'POSITIVE', 'NEGATIVE', 'POSITIVE', 'POSITIVE', 'POSITIVE', 'POSITIVE', 'POSITIVE', 'POSITIVE', 'POSITIVE', 'POSITIVE', 'NEUTRAL', 'POSITIVE', 'POSITIVE', 'POSITIVE', 'POSITIVE', 'POSITIVE', 'POSITIVE', 'POSITIVE', 'POSITIVE', 'POSITIVE', 'MIXED', 'POSITIVE', 'POSITIVE', 'POSITIVE', 'POSITIVE', 'POSITIVE', 'POSITIVE', 'POSITIVE', 'POSITIVE', 'POSITIVE', 'POSITIVE', 'POSITIVE', 'POSITIVE', 'POSITIVE', 'POSITIVE', 'POSITIVE', 'POSITIVE', 'POSITIVE', 'POSITIVE', 'POSITIVE', 'POSITIVE', 'POSITIVE', 'MIXED', 'POSITIVE', 'POSITIVE', 'POSITIVE', 'NEGATIVE', 'POSITIVE', 'POSITIVE', 'POSITIVE', 'POSITIVE', 'POSITIVE', 'POSITIVE', 'POSITIVE', 'POSITIVE', 'POSITIVE', 'POSITIVE', 'POSITIVE', 'POSITIVE', 'POSITIVE', 'POSITIVE', 'POSITIVE', 'MIXED', 'POSITIVE', 'POSITIVE', 'POSITIVE', 'POSITIVE', 'POSITIVE', 'MIXED', 'POSITIVE', 'POSITIVE', 'POSITIVE', 'POSITIVE', 'MIXED', 'POSITIVE', 'POSITIVE', 'MIXED', 'POSITIVE', 'POSITIVE', 'POSITIVE', 'POSITIVE', 'POSITIVE', 'POSITIVE', 'POSITIVE', 'POSITIVE', 'POSITIVE', 'POSITIVE', 'POSITIVE', 'POSITIVE', 'MIXED', 'POSITIVE', 'POSITIVE', 'POSITIVE', 'POSITIVE', 'POSITIVE', 'POSITIVE', 'MIXED', 'POSITIVE', 'POSITIVE', 'MIXED', 'POSITIVE', 'POSITIVE', 'POSITIVE', 'POSITIVE', 'POSITIVE', 'POSITIVE', 'POSITIVE', 'POSITIVE', 'POSITIVE', 'POSITIVE', 'MIXED', 'POSITIVE', 'POSITIVE', 'POSITIVE', 'POSITIVE', 'POSITIVE', 'POSITIVE', 'POSITIVE', 'POSITIVE', 'POSITIVE', 'POSITIVE', 'POSITIVE', 'POSITIVE', 'NEGATIVE', 'POSITIVE', 'POSITIVE', 'POSITIVE', 'POSITIVE', 'POSITIVE', 'POSITIVE', 'POSITIVE', 'POSITIVE', 'POSITIVE', 'MIXED', 'POSITIVE', 'POSITIVE', 'POSITIVE', 'POSITIVE', 'POSITIVE', 'POSITIVE', 'POSITIVE', 'POSITIVE', 'POSITIVE', 'POSITIVE', 'POSITIVE', 'NEUTRAL', 'POSITIVE', 'MIXED', 'POSITIVE', 'POSITIVE', 'POSITIVE', 'POSITIVE', 'POSITIVE', 'POSITIVE', 'POSITIVE', 'POSITIVE', 'POSITIVE', 'POSITIVE', 'POSITIVE', 'POSITIVE', 'POSITIVE', 'POSITIVE', 'MIXED', 'POSITIVE', 'POSITIVE', 'MIXED', 'POSITIVE', 'POSITIVE', 'POSITIVE', 'POSITIVE', 'MIXED', 'POSITIVE', 'MIXED', 'POSITIVE', 'POSITIVE', 'POSITIVE', 'POSITIVE', 'POSITIVE', 'POSITIVE', 'POSITIVE', 'POSITIVE', 'POSITIVE', 'POSITIVE', 'POSITIVE', 'POSITIVE', 'POSITIVE', 'POSITIVE', 'POSITIVE', 'NEGATIVE', 'POSITIVE', 'POSITIVE', 'POSITIVE', 'POSITIVE', 'POSITIVE', 'POSITIVE', 'POSITIVE', 'POSITIVE', 'POSITIVE', 'POSITIVE', 'PO ...

# %%
for idx, r in enumerate(review):
    print(r)
    print(results[idx])
# Out:
# Fits perfectly in my hand - I wish it has some more of the apps from the play store some are just not there
# NEGATIVE
# Simple to use - I like the unit but battery seems to run down more quickly that my previous Fire. Also gets warm while charging.
# POSITIVE
# Amazon Fire Tablet - I'm very happy with my purchase. I bought one because my wife has one and is very happy with hers.
# POSITIVE
# good - Am happy with my purchase and the item is being used by my brother's son and he is also happy as on dat
# POSITIVE
# Great little tablet if you dont need HD resolution - Amazon has consistently delivered quality tablets at the best prices and this is no exception.
# POSITIVE
# Easy access to my magazines and books. - Bought this tablet after a cheaper model quit working. I found all my cloud items already available being Prime Member.
# POSITIVE
# Great beginner tablet. - I reviewed a lot of tablets before I bought this one. It is the first one I have ever purchased. I am no tech geek and it was pretty easy to figure out how to use it. I mostly bought it for and use it for: reading e-mail, facebook, and browsing the internet. I really like it and use it more than my laptop. But, if I need to do anything detailed, I use my laptop. Overall it's a great tablet for a beginner, and you can't beat the price.
# POSITIVE
# Great Value - This device performs great! For the price it's really a steal. Affordable and easy to use.
# NEGATIVE
# awesome for games and movies - Bought this to use on my travels. comes in handy surfing the web.
# POSITIVE
# Decent Tablet - This is your basic Amazon taplet. Nothing too special about it.
# POSITIVE
# great gift for young teen - Purchased this for my fiance's youngest son for Christmas and also to replace his broken "no name" handheld. He loved it. The speed, ease of use and size were perfect for him. He mostly uses it for music, youtube and instagram..all of which seem to work fine on it. It was also very affordable. He's happy with it so we are too.
# POSITIVE
# Better than before! - The apps are better, it charges faster and the camera is really neat!
# POSITIVE
# So improved - My children love these kindles! They are so much better then the 1st ones we had & the price is better as well!
# POSITIVE
# EXCELLENT - This tablet is so great for school children to play and learn on.
# POSITIVE
# Great product, easy to use - This product was easy to set up and to use. Works great and has expandable storage which is nice.
# POSITIVE
# Its a gift - Tablets are best used for personal reading. Clear and it like a book. you dont have to sahre
# MIXED
# Good for my 11 year old son - My son uses the device to help him do his homework
# POSITIVE
# Great tablet! - My 6yr old son loves the tablet!I plan on purchasing another Fire tablet!
# POSITIVE
# Im so happy with this product - Reading is GREAT! - I APPRECIATE the ease of purchasing and reading ! I have found every book title I want plus the recommended books have led me to find new Authors!
# POSITIVE
# Very versatile - I love this tablet/kindle. I can access email, Facebook, play simple games, shop online and read my books.
# MIXED
# Good product - This is a great tablet for the price. Amazon is doing a good job
# NEGATIVE
# Great Tablet - This tablet is the perfect size and so easy to use. Read, play games or any other purpose--it is great!
# MIXED
# Great for kids or smaller needs - Purchased this for my son. Has room to upgrade memory to allow more books & games. But the speakers could be better or located in a better position.
# POSITIVE
# Very sturdy for a 5 year old - I had some thoughts about getting this for a 5 year old, but if you get the screen protector and a case I feel it will last a long time.
# POSITIVE
# great little tablet - this is a steal, have 8 gb model as well.This has more punch..
# POSITIVE

# %%
# Add Sentiments to the data frame
df['sentiment']=results

# %%
df.head()
# Out:
#                      id             dateAdded           dateUpdated  \
# 0  AVqVGZNvQMlgsOJE6eUY  2017-03-03T16:56:05Z  2018-10-25T16:36:31Z
# 1  AVqVGZNvQMlgsOJE6eUY  2017-03-03T16:56:05Z  2018-10-25T16:36:31Z
# 2  AVqVGZNvQMlgsOJE6eUY  2017-03-03T16:56:05Z  2018-10-25T16:36:31Z
# 3  AVqVGZNvQMlgsOJE6eUY  2017-03-03T16:56:05Z  2018-10-25T16:36:31Z
# 4  AVqVGZNvQMlgsOJE6eUY  2017-03-03T16:56:05Z  2018-10-25T16:36:31Z
#
#                                                 name       asins   brand  \
# 0  Amazon Kindle E-Reader 6" Wifi (8th Generation...  B00ZV9PXP2  Amazon
# 1  Amazon Kindle E-Reader 6" Wifi (8th Generation...  B00ZV9PXP2  Amazon
# 2  Amazon Kindle E-Reader 6" Wifi (8th Generation...  B00ZV9PXP2  Amazon
# 3  Amazon Kindle E-Reader 6" Wifi (8th Generation...  B00ZV9PXP2  Amazon
# 4  Amazon Kindle E-Reader 6" Wifi (8th Generation...  B00ZV9PXP2  Amazon
#
#                                           categories primaryCategories  \
# 0  Computers,Electronics Features,Tablets,Electro...       Electronics
# 1  Computers,Electronics Features,Tablets,Electro...       Electronics
# 2  Computers,Electronics Features,Tablets,Electro...       Electronics
# 3  Computers,Electronics Features,Tablets,Electro...       Electronics
# 4  Computers,Electronics Features,Tablets,Electro...       Electronics
#
#                                            imageURLs  \
# 0  https://pisces.bbystatic.com/image2/BestBuy_US...
# 1  https://pisces.bbystatic.com/image2/BestBuy_US...
# 2  https://pisces.bbystatic.com/image2/BestBuy_US...
# 3  https://pisces.bbystatic.com/image2/BestBuy_US...
# 4  https://pisces.bbystatic.com/image2/BestBuy_US...
#
#                                                 keys  ... reviews.doRecommend  \
# 0  allnewkindleereaderblack6glarefreetouchscreend...  ...               False
# 1  allnewkindleereaderblack6glarefreetouchscreend...  ...                True
# 2  allnewkindleereaderblack6glarefreetouchscreend...  ...                True
# 3  allnewkindleereaderblack6glarefreetouchscreend...  ...                True
# 4  allnewkindleereaderblack6glarefreetouchscreend...  ...                True
#
#     reviews.id reviews.numHelpful reviews.rating  \
# 0          NaN                  0              3
# 1          NaN                  0              5
# 2          NaN                  0              4
# 3  177283626.0                  3              5
# 4          NaN                  0              5
#
#                                   reviews.sourceURLs  \
# 0  http://reviews.bestbuy.com/3545/5442403/review...
# 1  http://reviews.bestbuy.com/3545/5442403/review...
# 2  https://reviews.bestbuy.com/3545/5442403/revie...
# 3  https://redsky.target.com/groot-domain-api/v1/...
# 4  https://reviews.bestbuy.com/3545/5442403/revie...
#
#                                         reviews.text  \
# 0  I thought it would be as big as small paper bu...
# 1  This kindle is light and easy to use especiall...
# 2  Didnt know how much i'd use a kindle so went f...
# 3  I am 100 happy with my purchase. I caught it o...
# 4  Solid entry level Kindle. Great for kids. Gift...
#
#                                   reviews.title  reviews.username  \
# 0                                     Too small            llyyue
# 1  Great light reader. Easy to use at the beach            Charmi
# 2                           Great for the price      johnnyjojojo
# 3                                   A Great Buy           Kdperry
# 4      Solid entry-level Kindle. Great for kids       Johnnyblack
#
#                                           sourceURLs sentiment
# 0  https://www.newegg.com/Product/Product.aspx%25...  NEGATIVE
# 1  https://www.newegg.com/Product/Product.aspx%25...  POSITIVE
# 2  https://www.newegg.com/Product/Product.aspx%25...  POSITIVE
# 3  https://www.newegg.com/Product/Product.aspx%25...  POSITIVE
# 4  https://www.newegg.com/Product/Product.aspx%25...  POSITIVE
#
# [5 rows x 25 columns]

# %% [markdown]
# ### Copy the file to your bucket

# %%
df.to_csv('s3://amazon-reviews-multilingual/Datafiniti_Amazon_Consumer_Reviews_of_Amazon_Products_with_sentiment.csv', index=False)
